# %% [markdown]
# <a href="https://colab.research.google.com/github/olilambourn/olilambourn.github.io/blob/main/HDI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = "https://en.wikipedia.org/wiki/List_of_countries_by_Human_Development_Index"
r = requests.get(URL)

# %%
soup = BeautifulSoup(r.content)
table = soup.find('table')

df = pd.read_html(str(table))[0]

# Set the maximum number of rows to be displayed to the number of rows in the DataFrame
pd.set_option('display.max_rows', df.shape[0])

df
# Out:
#                     Dimensions  \
# 0        Long and healthy life
# 1                    Knowledge
# 2  A decent standard of living
#
#                                           Indicators        Dimension index  \
# 0                           Life expectancy at birth  Life expectancy index
# 1  Expected years of schoolingMean years of schoo...        Education index
# 2                             GNI per capita (PPP $)              GNI index
#
#                        HDI
# 0  Human Development Index
# 1  Human Development Index
# 2  Human Development Index

# %%
# Set the maximum number of rows to be displayed to the number of rows in the DataFrame
pd.set_option('display.max_rows', df2.shape[0])

df2
# Out:
#                            Rank                         \
#     2021 data (2022 report)​[2] Change since 2015​[20]
# 0                             1                    NaN
# 1                             2                    NaN
# 2                             3                    NaN
# 3                             4                    (3)
# 4                             5                    (3)
# 5                             6                    NaN
# 6                             7                    (2)
# 7                             8                    (6)
# 8                             9                    (5)
# 9                            10                    (1)
# 10                           11                    NaN
# 11                           12                    (1)
# 12                           13                    (2)
# 13                           13                    (3)
# 14                           15                    (2)
# ...

# %%
# Drop the second column
df3 = df2.drop(df2.columns[1], axis=1)

df3
# Out:
#                            Rank                            Nation  \
#     2021 data (2022 report)​[2]                            Nation
# 0                             1                       Switzerland
# 1                             2                            Norway
# 2                             3                           Iceland
# 3                             4                         Hong Kong
# 4                             5                         Australia
# 5                             6                           Denmark
# 6                             7                            Sweden
# 7                             8                           Ireland
# 8                             9                           Germany
# 9                            10                       Netherlands
# 10                           11                           Finland
# 11                           12                         Singapore
# ...

# %%
# Drop the fourth column
df4 = df3.drop(df3.columns[3], axis=1)

df4
# Out:
#                            Rank                            Nation  \
#     2021 data (2022 report)​[2]                            Nation
# 0                             1                       Switzerland
# 1                             2                            Norway
# 2                             3                           Iceland
# 3                             4                         Hong Kong
# 4                             5                         Australia
# 5                             6                           Denmark
# 6                             7                            Sweden
# 7                             8                           Ireland
# 8                             9                           Germany
# 9                            10                       Netherlands
# 10                           11                           Finland
# 11                           12                         Singapore
# ...

# %%
# Save the DataFrame as a CSV file
df4.to_csv('HDI.csv', index=False)
