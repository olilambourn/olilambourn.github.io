# %% [markdown]
# <a href="https://colab.research.google.com/github/olilambourn/olilambourn.github.io/blob/main/machinelearning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_html('https://github.com/olilambourn/olilambourn.github.io/blob/main/energyefficiency.csv')
# Out:
# [     Unnamed: 0    X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
#  0           NaN  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
#  1           NaN  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
#  2           NaN  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
#  3           NaN  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
#  4           NaN  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
#  ..          ...   ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
#  763         NaN  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
#  764         NaN  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
#  765         NaN  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
#  766         NaN  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
#  767         NaN  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
#  [768 rows x 11 columns]]

# %%
table_list = pd.read_html('https://github.com/olilambourn/olilambourn.github.io/blob/main/energyefficiency.csv')
table_list[0]
# Out:
#      Unnamed: 0    X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0           NaN  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1           NaN  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2           NaN  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3           NaN  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4           NaN  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..          ...   ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763         NaN  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764         NaN  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765         NaN  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766         NaN  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767         NaN  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 11 columns]

# %%
table = table_list[0]

# %%
#Dropping columns that aren't needed
table1 = table.drop(['Unnamed: 0', 'X2', 'X3', 'X4', 'Y2'], axis=1)

# %%
table1
# Out:
#        X1   X5  X6   X7  X8     Y1
# 0    0.98  7.0   2  0.0   0  15.55
# 1    0.98  7.0   3  0.0   0  15.55
# 2    0.98  7.0   4  0.0   0  15.55
# 3    0.98  7.0   5  0.0   0  15.55
# 4    0.90  7.0   2  0.0   0  20.84
# ..    ...  ...  ..  ...  ..    ...
# 763  0.64  3.5   5  0.4   5  17.88
# 764  0.62  3.5   2  0.4   5  16.54
# 765  0.62  3.5   3  0.4   5  16.44
# 766  0.62  3.5   4  0.4   5  16.48
# 767  0.62  3.5   5  0.4   5  16.64
#
# [768 rows x 6 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
X = df[['X1']]
y = df[['Y1']]

# %%
X1Y1 = LinearRegression()
X1Y1.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y)

# %%
yp = X1Y1.predict(X)
yp
# Out:
# array([[35.11885726],
#        [35.11885726],
#        [35.11885726],
#        [35.11885726],
#        [30.37013507],
#        [30.37013507],
#        [30.37013507],
#        [30.37013507],
#        [27.99577398],
#        [27.99577398],
#        [27.99577398],
#        [27.99577398],
#        [25.62141288],
#        [25.62141288],
#        [25.62141288],
#        [25.62141288],
#        [23.84064206],
#        [23.84064206],
#        [23.84064206],
#        [23.84064206],
#        [22.05987124],
#        [22.05987124],
#        [22.05987124],
#        [22.05987124],
#        [20.87269069],
#        [20.87269069],
#        [20.87269069],
#        [20.87269069],
#        [19.09191987],
#        [19.09191987],
#        [19.09191987],
#        [19.09191987],
#        [17.90473932],
#        [17.90473932],
#        [17.90473932],
#        [17.90473932],
#        [16.1239685 ],
#        [16.1239685 ],
#        [16.1239685 ],
#        [16.1239685 ],
#        [14.93678796],
# ...

# %%
plt.scatter(X, yp)

# %%
#Finding out R Squared
r_squared = X1Y1.score(X, y)
r_squared
# Out:
# 0.3872226648378837

# %%
plt.scatter(X, y, color='#710193')
plt.plot(X, yp, color='#ea12ab')
plt.xlabel('X1')
ax = plt.axes()
ax.set_facecolor('white')
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
plt.ylabel('Y1')
plt.annotate(f'R\u00b2 = {r_squared:.2f}', xy=(0.7, 0.2), xycoords='axes fraction')
plt.title('Relative Compactness vs Heating Load', fontweight='bold')
# Out:
# <ipython-input-33-2d208ebf55f5>:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()
# Text(0.5, 1.0, 'Relative Compactness vs Heating Load')

# %%
plt.savefig('X1Y1.pdf')
